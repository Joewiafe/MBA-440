# %% [markdown]
# <a href="https://colab.research.google.com/github/Joewiafe/MBA-440/blob/main/EDAassignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/chiharuishida/Tutorialdata/main/ad_dataset_withheaders.csv"
Joey = pd.read_csv(url)

# %%
Joey.head(10)
#provides the first 10 raw of data. this provides a quick view of the dataset titled "tips"
# Out:
#    Site_Time  Age  DailyTime  Gender AdClicking
# 0      68.95   35     256.09  Female         No
# 1      80.23   31     193.77    Male         No
# 2      69.47   26     236.50  Female         No
# 3      74.15   29     245.89    Male         No
# 4      68.37   35     225.58  Female         No
# 5      59.99   23     226.74    Male         No
# 6      88.91   33     208.36  Female         No
# 7      66.00   48     131.76    Male        Yes
# 8      74.53   30     221.51    Male         No
# 9      69.88   20     183.82    Male         No

# %%
Joey.describe()
#quickly provides a descriptive statistics for all the continous variables in the dataset
# Out:
#          Site_Time          Age    DailyTime
# count  1000.000000  1000.000000  1000.000000
# mean     65.000200    36.009000   180.000100
# std      15.853615     8.785562    43.902339
# min      32.600000    19.000000   104.780000
# 25%      51.360000    29.000000   138.830000
# 50%      68.215000    35.000000   183.130000
# 75%      78.547500    42.000000   218.792500
# max      91.430000    61.000000   269.960000

# %%
Joey.info()
#provides information about each variable in the dataset. Dtype of float is a number with a decimal place, while int is for intege
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Site_Time   1000 non-null   float64
#  1   Age         1000 non-null   int64
#  2   DailyTime   1000 non-null   float64
#  3   Gender      1000 non-null   object
#  4   AdClicking  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
Joey['Gender'].value_counts()
#"day" is a categorical variable in our data
# Out:
# Female    519
# Male      481
# Name: Gender, dtype: int64

# %%
Joey.corr()
#quickly provides a correlation matrix
# Out:
#            Site_Time       Age  DailyTime
# Site_Time   1.000000 -0.331513   0.518658
# Age        -0.331513  1.000000  -0.367209
# DailyTime   0.518658 -0.367209   1.000000

# %%
sns.heatmap(Joey.corr(), annot=True)
#annot=True adds an annotation to the right

# %%
sns.heatmap(Joey.corr(), cmap="YlGnBu")
#just changing colors here for better looks (darker=greater value)
#other colormap options are 'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds','YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu','GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn'

# %%
sns.pairplot(Joey)
#quickly provides pairplot between the continous varialbles.

# %%
sns.scatterplot(x="Age", y="Site_Time", data=Joey)
#let's just look at the scatterplot between "top" and "total_bill"
#A scatterplot is for any two continuous variables

# %%
sns.lmplot(x = "Age", y = "Site_Time", data = Joey)
#fitting a trendline

# %%
sns.scatterplot(x="Age", y="Site_Time", hue="Gender", data=Joey)
#adding color-coding by smoker-nonsmoker by adding the hue statement

# %%
sns.lmplot(x = "Age", y = "Site_Time", hue="Gender", data = Joey)
#Fitting lines for the two smoker categories

# %%
sns.countplot(x='Gender', data=Joey)
#barchart sorted by "day" which is a categorical variable

# %%
sns.countplot(x='Gender', data=Joey, color='r')
#changing color to all red by adding "color='r'"

# %%
Joey_Gender=Joey.groupby("Gender")
Joey_Gender.mean()
#groupby() is used to split the data in dataframe into groups ("tips_day" is created as a new dataframe)
#"day" is a categorical variable
# Out:
#         Site_Time        Age   DailyTime
# Gender
# Female  65.289287  36.186898  178.816763
# Male    64.688274  35.817048  181.276923

# %%
sns.boxplot(x="Gender", y="Age", data=Joey)
#quickly creating boxplots. Here, "day" is a categorical variable" and "tip" is a continuous variable

# %%
sns.boxplot(x="Site_Time", y="Age", hue="Gender", data=Joey)
#adding a color code by using hue. In this case, we are using the "smoker" variable, which is a categorical variable

# %%
Joey_top3_Joey = Joey.nlargest(3, "Age")
Joey_top3_Joey
#.nlargest()is a method to quickly get TopN results for the continous variable of "tip". It will list the top 3 tippers. For this analysis, select a continuous variable
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 671      66.08   61     184.23    Male        Yes
# 110      66.63   60     176.98  Female        Yes
# 182      62.95   60     157.04  Female        Yes
